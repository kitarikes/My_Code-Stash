# %%
#Hey what up,people! Hope you're having a good day! 
#Here I'm gonna show ya how to set up YOLOv3 the darknet version on Colab
#And use it to process images, video, and, especially, TRAIN your models!!
#You can contant me at https://twitter.com/Ivangrov, if you have questions
#Or something's not working
#Are you excited? Let's go!
#Don't forget to select GPU! 


#First, let's get some updates
# !apt-get update
# !apt-get upgrade
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Get:2 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Ign:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu bionic InRelease
# Ign:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [697 B]
# Get:7 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release [564 B]
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Get:10 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# ...

# %%
# !apt-get install build-essential
# !apt-get install cmake git libgtk2.0-dev pkg-config libavcodec-dev libavformat-dev libswscale-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# build-essential is already the newest version (12.4ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 4 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# pkg-config is already the newest version (0.29.1-0ubuntu2).
# cmake is already the newest version (3.10.2-1ubuntu2.18.04.1).
# git is already the newest version (1:2.17.1-1ubuntu0.7).
# libavcodec-dev is already the newest version (7:3.4.8-0ubuntu0.2).
# libavcodec-dev set to manually installed.
# libavformat-dev is already the newest version (7:3.4.8-0ubuntu0.2).
# libavformat-dev set to manually installed.
# libswscale-dev is already the newest version (7:3.4.8-0ubuntu0.2).
# libswscale-dev set to manually installed.
# The following additional packages will be installed:
#   autoconf automake autopoint autotools-dev debhelper dh-autoreconf
# ...

# %%
# !apt-get install libavcodec-dev libavformat-dev libswscale-d
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# E: Unable to locate package libswscale-d

# %%
# !apt-get -y install cmake
# !which cmake

# !cmake --version
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# cmake is already the newest version (3.10.2-1ubuntu2.18.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 4 not upgraded.
# /usr/local/bin/cmake
# cmake version 3.12.0
#
# CMake suite maintained and supported by Kitware (kitware.com/cmake).

# %%
# !apt-get install libopencv-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libopencv-dev is already the newest version (3.2.0+dfsg-4ubuntu0.1).
# 0 upgraded, 0 newly installed, 0 to remove and 4 not upgraded.

# %%
# !apt install g++-5
# !apt install gcc-5

# !update-alternatives --install /usr/bin/gcc gcc /usr/bin/gcc-5 10
# !update-alternatives --install /usr/bin/gcc gcc /usr/bin/gcc-5 20
# !update-alternatives --install /usr/bin/g++ g++ /usr/bin/g++-5 10
# !update-alternatives --install /usr/bin/g++ g++ /usr/bin/g++-5 20
# !update-alternatives --install /usr/bin/cc cc /usr/bin/gcc 30
# !update-alternatives --set cc /usr/bin/gcc
# !update-alternatives --install /usr/bin/c++ c++ /usr/bin/g++ 30
# !update-alternatives --set c++ /usr/bin/g++
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   cpp-5 gcc-5 gcc-5-base libasan2 libgcc-5-dev libisl15 libmpx0
#   libstdc++-5-dev
# Suggested packages:
#   gcc-5-locales g++-5-multilib gcc-5-doc libstdc++6-5-dbg gcc-5-multilib
#   libgcc1-dbg libgomp1-dbg libitm1-dbg libatomic1-dbg libasan2-dbg
#   liblsan0-dbg libtsan0-dbg libubsan0-dbg libcilkrts5-dbg libmpx0-dbg
#   libquadmath0-dbg libstdc++-5-doc
# The following NEW packages will be installed:
#   cpp-5 g++-5 gcc-5 gcc-5-base libasan2 libgcc-5-dev libisl15 libmpx0
#   libstdc++-5-dev
# 0 upgraded, 9 newly installed, 0 to remove and 29 not upgraded.
# Need to get 29.1 MB of archives.
# After this operation, 100 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 gcc-5-base amd64 5.5.0-12ubuntu1 [17.1 kB]
# ...

# %%
#Now, here's a bunch of code that takes the longest to execute here but
#It's about installing CUDA and using the beautiful Tesla K80 GPU, so that
#Will worth it

# !apt update -qq;
# !wget https://developer.nvidia.com/compute/cuda/8.0/Prod2/local_installers/cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb
# !dpkg -i cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb
# !apt-get update -qq

#Here were are installing compilers and creating some links
# !apt-get install cuda -y -qq #gcc-5 g++-5 
#!ln -s /usr/bin/gcc-5 /usr/local/cuda/bin/gcc
#!ln -s /usr/bin/g++-5 /usr/local/cuda/bin/g++
# !apt update
# !apt upgrade
# !apt install cuda-8.0 -y
# Out:
# 40 packages can be upgraded. Run 'apt list --upgradable' to see them.
# --2021-03-09 07:02:43--  https://developer.nvidia.com/compute/cuda/8.0/Prod2/local_installers/cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb
# Resolving developer.nvidia.com (developer.nvidia.com)... 152.199.16.29
# Connecting to developer.nvidia.com (developer.nvidia.com)|152.199.16.29|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://developer.nvidia.com/compute/cuda/8.0/prod2/local_installers/cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb [following]
# --2021-03-09 07:02:43--  https://developer.nvidia.com/compute/cuda/8.0/prod2/local_installers/cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb
# Reusing existing connection to developer.nvidia.com:443.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
! nvcc -V
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2016 NVIDIA Corporation
# Built on Tue_Jan_10_13:22:03_CST_2017
# Cuda compilation tools, release 8.0, V8.0.61

# %%
#Now let's see whether the GPU is here and CUDA was successfully installed!
import tensorflow as tf
device_name = tf.test.gpu_device_name()
print(device_name)

print("'sup!'")

# !/usr/local/cuda/bin/nvcc --version
# Out:
# /device:GPU:0
# 'sup!'
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2016 NVIDIA Corporation
# Built on Tue_Jan_10_13:22:03_CST_2017
# Cuda compilation tools, release 8.0, V8.0.61

# %%
# %cd "/content/drive/My Drive/darknet"
# Out:
# /content/drive/My Drive/darknet

# %%
! nvcc -V
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Wed_Jul_22_19:09:09_PDT_2020
# Cuda compilation tools, release 11.0, V11.0.221
# Build cuda_11.0_bu.TC445_37.28845127_0

# %%
! dpkg -l | grep "cudnn"
# Out:
# ii  libcudnn7                              7.6.5.32-1+cuda10.1                 amd64        cuDNN runtime libraries
# ii  libcudnn7-dev                          7.6.5.32-1+cuda10.1                 amd64        cuDNN development libraries and headers
# hi  libcudnn8                              8.0.4.30-1+cuda11.0                 amd64        cuDNN runtime libraries
# ii  libcudnn8-dev                          8.0.4.30-1+cuda11.0                 amd64        cuDNN development libraries and headers

# %%
import tensorflow as tf; print(tf.__version__)
# Out:
# 2.4.1

# %%
# %cd rgb-task
# Out:
# /content/drive/My Drive/darknet/rgb-task

# %%
# !unzip data.zip
# Out:
# Archive:  data.zip
#    creating: data/
#   inflating: data/IMG_1639.JPG
#  extracting: data/IMG_1639.txt
#   inflating: data/IMG_1640.JPG
#  extracting: data/IMG_1640.txt
#   inflating: data/IMG_1641.JPG
#  extracting: data/IMG_1641.txt
#   inflating: data/IMG_1642.JPG
#  extracting: data/IMG_1642.txt
#   inflating: data/IMG_1643.JPG
#  extracting: data/IMG_1643.txt
#   inflating: data/IMG_1644.JPG
#  extracting: data/IMG_1644.txt
#   inflating: data/IMG_1645.JPG
#  extracting: data/IMG_1645.txt
#   inflating: data/IMG_1646.JPG
#  extracting: data/IMG_1646.txt
#   inflating: data/IMG_1647.JPG
#   inflating: data/IMG_1647.txt
#   inflating: data/IMG_1648.JPG
#   inflating: data/IMG_1648.txt
#   inflating: data/IMG_1649.JPG
#  extracting: data/IMG_1649.txt
#   inflating: data/IMG_1650.JPG
#  extracting: data/IMG_1650.txt
#   inflating: data/IMG_1652.JPG
#  extracting: data/IMG_1652.txt
#   inflating: data/IMG_1653.JPG
#  extracting: data/IMG_1653.txt
#   inflating: data/IMG_1657.JPG
# ...

# %%
#!unzip task-cfg.zip
# Out:
# Archive:  task-cfg.zip
#    creating: task-cfg/
#   inflating: task-cfg/obj.data
#   inflating: task-cfg/obj.names
#   inflating: task-cfg/yolov3-obj.cfg

# %%
#%cd ..
# Out:
# /content/drive/My Drive/darknet

# %%
#cat process.py
# Out:
# import glob, os
#
# # Current directory
# current_dir = os.path.dirname(os.path.abspath(__file__))
# task_name = os.path.join(current_dir, 'task1/')
#
# # Directory where the data will reside, relative to 'darknet.exe'
# path_data = task_name + 'data/'
#
# # Percentage of images to be used for the test set
# percentage_test = 20
#
# # Create and/or truncate train.txt and test.txt
# file_train = open(task_name + 'train.txt', 'w')
# file_test = open(task_name + 'test.txt', 'w')
#
# # Populate train.txt and test.txt
# counter = 1
# index_test = round(100 / percentage_test)
# for pathAndFilename in glob.iglob(os.path.join(path_data, "*.JPEG")):
#     title, ext = os.path.splitext(os.path.basename(pathAndFilename))
#
#     if counter == index_test:
#         counter = 1
#         file_test.write(path_data + title + '.JPEG' + "\n")
#     else:
#         file_train.write(path_data + title + '.JPEG' + "\n")
#         counter = counter + 1

# %%
# %%writefile process.py
import glob, os

# Current directory
current_dir = os.path.dirname(os.path.abspath(__file__))
task_name = os.path.join(current_dir, 'rgb-task/')

# Directory where the data will reside, relative to 'darknet.exe'
path_data = task_name + 'data/'

# Percentage of images to be used for the test set
percentage_test = 20

# Create and/or truncate train.txt and test.txt
file_train = open(task_name + 'train.txt', 'w')  
file_test = open(task_name + 'test.txt', 'w')

# Populate train.txt and test.txt
counter = 1  
index_test = round(100 / percentage_test)  
for pathAndFilename in glob.iglob(os.path.join(path_data, "*.JPG")):  
    title, ext = os.path.splitext(os.path.basename(pathAndFilename))

    if counter == index_test:
        counter = 1
        file_test.write(path_data + title + '.JPG' + "\n")
    else:
        file_train.write(path_data + title + '.JPG' + "\n")
        counter = counter + 1
# Out:
# Overwriting process.py

# %%
# !python process.py

# %%
# %cd rgb-task
# Out:
# /content/drive/My Drive/darknet/rgb-task

# %%
cat train.txt
# Out:
# /content/drive/My Drive/darknet/rgb-task/data/IMG_1639.JPG
# /content/drive/My Drive/darknet/rgb-task/data/IMG_1640.JPG
# /content/drive/My Drive/darknet/rgb-task/data/IMG_1641.JPG
# /content/drive/My Drive/darknet/rgb-task/data/IMG_1642.JPG
# /content/drive/My Drive/darknet/rgb-task/data/IMG_1644.JPG
# /content/drive/My Drive/darknet/rgb-task/data/IMG_1645.JPG
# /content/drive/My Drive/darknet/rgb-task/data/IMG_1646.JPG
# /content/drive/My Drive/darknet/rgb-task/data/IMG_1647.JPG
# /content/drive/My Drive/darknet/rgb-task/data/IMG_1649.JPG
# /content/drive/My Drive/darknet/rgb-task/data/IMG_1650.JPG
# /content/drive/My Drive/darknet/rgb-task/data/IMG_1652.JPG
# /content/drive/My Drive/darknet/rgb-task/data/IMG_1653.JPG
# /content/drive/My Drive/darknet/rgb-task/data/IMG_1658.JPG
# /content/drive/My Drive/darknet/rgb-task/data/IMG_1663.JPG
# /content/drive/My Drive/darknet/rgb-task/data/IMG_1664.JPG
# /content/drive/My Drive/darknet/rgb-task/data/IMG_1679.JPG
# ...

# %%
# %%writefile train.txt
# ./rgb-task/data/IMG_1639.JPG
# ./rgb-task/data/IMG_1640.JPG
# ./rgb-task/data/IMG_1641.JPG
# ./rgb-task/data/IMG_1642.JPG
# ./rgb-task/data/IMG_1644.JPG
# ./rgb-task/data/IMG_1645.JPG
# ./rgb-task/data/IMG_1646.JPG
# ./rgb-task/data/IMG_1647.JPG
# ./rgb-task/data/IMG_1649.JPG
# ./rgb-task/data/IMG_1650.JPG
# ./rgb-task/data/IMG_1652.JPG
# ./rgb-task/data/IMG_1653.JPG
# ./rgb-task/data/IMG_1658.JPG
# ./rgb-task/data/IMG_1663.JPG
# ./rgb-task/data/IMG_1664.JPG
# ./rgb-task/data/IMG_1679.JPG
# ./rgb-task/data/IMG_1683.JPG
# ./rgb-task/data/IMG_1684.JPG
# ./rgb-task/data/IMG_1687.JPG
# ./rgb-task/data/IMG_1688.JPG
# ./rgb-task/data/IMG_1852.JPG
# ./rgb-task/data/IMG_1853.JPG
# ./rgb-task/data/IMG_1854.JPG
# ./rgb-task/data/IMG_1855.JPG
# ./rgb-task/data/IMG_1857.JPG
# ./rgb-task/data/IMG_1858.JPG
# ./rgb-task/data/IMG_1859.JPG
# ./rgb-task/data/IMG_1860.JPG
# ./rgb-task/data/IMG_1865.JPG
# ./rgb-task/data/IMG_1866.JPG
# ./rgb-task/data/IMG_1871.JPG
# ./rgb-task/data/IMG_1872.JPG
# ./rgb-task/data/IMG_1879.JPG
# ./rgb-task/data/IMG_1880.JPG
# ./rgb-task/data/IMG_1881.JPG
# ./rgb-task/data/IMG_1882.JPG
# ./rgb-task/data/IMG_1884.JPG
# ./rgb-task/data/IMG_1885.JPG
# ./rgb-task/data/IMG_1886.JPG
# ./rgb-task/data/IMG_1887.JPG
# ./rgb-task/data/IMG_1889.JPG
# ./rgb-task/data/IMG_1890.JPG
# ./rgb-task/data/IMG_9237.JPG
# ./rgb-task/data/IMG_9238.JPG
# ./rgb-task/data/IMG_9240.JPG
# ./rgb-task/data/IMG_9241.JPG
# ./rgb-task/data/IMG_9242.JPG
# ./rgb-task/data/IMG_9243.JPG
# ./rgb-task/data/IMG_9245.JPG
# ./rgb-task/data/IMG_9246.JPG
# ./rgb-task/data/IMG_9247.JPG
# ./rgb-task/data/IMG_9248.JPG
# ./rgb-task/data/IMG_9250.JPG
# ./rgb-task/data/IMG_9251.JPG
# Out:
# Overwriting train.txt

# %%
cat test.txt
# Out:
# /content/drive/My Drive/darknet/rgb-task/data/IMG_1643.JPG
# /content/drive/My Drive/darknet/rgb-task/data/IMG_1648.JPG
# /content/drive/My Drive/darknet/rgb-task/data/IMG_1657.JPG
# /content/drive/My Drive/darknet/rgb-task/data/IMG_1680.JPG
# /content/drive/My Drive/darknet/rgb-task/data/IMG_1851.JPG
# /content/drive/My Drive/darknet/rgb-task/data/IMG_1856.JPG
# /content/drive/My Drive/darknet/rgb-task/data/IMG_1861.JPG
# /content/drive/My Drive/darknet/rgb-task/data/IMG_1878.JPG
# /content/drive/My Drive/darknet/rgb-task/data/IMG_1883.JPG
# /content/drive/My Drive/darknet/rgb-task/data/IMG_1888.JPG
# /content/drive/My Drive/darknet/rgb-task/data/IMG_9239.JPG
# /content/drive/My Drive/darknet/rgb-task/data/IMG_9244.JPG
# /content/drive/My Drive/darknet/rgb-task/data/IMG_9249.JPG

# %%
# %%writefile test.txt
# ./rgb-task/data/IMG_1643.JPG
# ./rgb-task/data/IMG_1648.JPG
# ./rgb-task/data/IMG_1657.JPG
# ./rgb-task/data/IMG_1680.JPG
# ./rgb-task/data/IMG_1851.JPG
# ./rgb-task/data/IMG_1856.JPG
# ./rgb-task/data/IMG_1861.JPG
# ./rgb-task/data/IMG_1878.JPG
# ./rgb-task/data/IMG_1883.JPG
# ./rgb-task/data/IMG_1888.JPG
# ./rgb-task/data/IMG_9239.JPG
# ./rgb-task/data/IMG_9244.JPG
# ./rgb-task/data/IMG_9249.JPG
# Out:
# Overwriting test.txt

# %%
# %cd ..
# Out:
# /content/drive/My Drive/darknet

# %%
# !make clean
# Out:
# rm -rf ./obj/gemm.o ./obj/utils.o ./obj/cuda.o ./obj/deconvolutional_layer.o ./obj/convolutional_layer.o ./obj/list.o ./obj/image.o ./obj/activations.o ./obj/im2col.o ./obj/col2im.o ./obj/blas.o ./obj/crop_layer.o ./obj/dropout_layer.o ./obj/maxpool_layer.o ./obj/softmax_layer.o ./obj/data.o ./obj/matrix.o ./obj/network.o ./obj/connected_layer.o ./obj/cost_layer.o ./obj/parser.o ./obj/option_list.o ./obj/detection_layer.o ./obj/route_layer.o ./obj/upsample_layer.o ./obj/box.o ./obj/normalization_layer.o ./obj/avgpool_layer.o ./obj/layer.o ./obj/local_layer.o ./obj/shortcut_layer.o ./obj/logistic_layer.o ./obj/activation_layer.o ./obj/rnn_layer.o ./obj/gru_layer.o ./obj/crnn_layer.o ./obj/demo.o ./obj/batchnorm_layer.o ./obj/region_layer.o ./obj/reorg_layer.o ./obj/tree.o ./obj/lstm_layer.o ./obj/l2norm_layer.o ./obj/yolo_layer.o ./obj/iseg_layer.o ./obj/image_opencv.o ./obj/convolutional_kernels.o ./obj/deconvolutional_kernels.o ./obj/activation_kernels.o ./obj/im2col_kernels.o ./obj
# ...

# %%
# !make
# Out:
# gcc -Iinclude/ -Isrc/ -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -DCUDNN  -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -c ./src/gemm.c -o obj/gemm.o
# gcc -Iinclude/ -Isrc/ -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -DCUDNN  -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -c ./src/utils.c -o obj/utils.o
# gcc -Iinclude/ -Isrc/ -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -DCUDNN  -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -c ./src/cuda.c -o obj/cuda.o
# gcc -Iinclude/ -Isrc/ -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -DCUDNN  -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -c ./src/deconvolutional_layer.c -o obj/deconvolutional_layer.o
# ...

# %%
# !sudo ./darknet detector train rgb-task/obj.data rgb-task/yolov3-obj.cfg darknet53.conv.74 -dont_show -map
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.423833, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: 0.109338, Class: 0.294038, Obj: 0.246918, No Obj: 0.482163, .5R: 0.000000, .75R: 0.000000,  count: 4
# Region 106 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.403010, .5R: -nan, .75R: -nan,  count: 0
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.423097, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: 0.135177, Class: 0.480732, Obj: 0.326919, No Obj: 0.481098, .5R: 0.000000, .75R: 0.000000,  count: 4
# Region 106 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.399582, .5R: -nan, .75R: -nan,  count: 0
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.422734, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: 0.300847, Class: 0.627744, Obj: 0.402476, No Obj: 0.480822, .5R: 0.250000, .75R: 0.000000,  count: 4
# ...

# %%
# !sudo ./darknet detector train rgb-task/obj.data rgb-task/yolov3-obj.cfg rgb-task/backup/yolov3-obj_700.weights -dont_show -map
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000133, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: 0.581296, Class: 0.952389, Obj: 0.526746, No Obj: 0.000207, .5R: 0.714286, .75R: 0.285714,  count: 7
# Region 82 Avg IOU: 0.127724, Class: 0.933069, Obj: 0.514626, No Obj: 0.000407, .5R: 0.000000, .75R: 0.000000,  count: 1
# Region 94 Avg IOU: 0.673072, Class: 0.934478, Obj: 0.427356, No Obj: 0.000185, .5R: 1.000000, .75R: 0.000000,  count: 1
# Region 106 Avg IOU: 0.612921, Class: 0.988526, Obj: 0.516177, No Obj: 0.000115, .5R: 0.666667, .75R: 0.000000,  count: 3
# Region 82 Avg IOU: 0.054084, Class: 0.959326, Obj: 0.356072, No Obj: 0.000340, .5R: 0.000000, .75R: 0.000000,  count: 1
# Region 94 Avg IOU: 0.382080, Class: 0.900249, Obj: 0.321222, No Obj: 0.000189, .5R: 0.000000, .75R: 0.000000,  count: 2
# Region 106 Avg IOU: 0.587097, Class: 0.860035, Obj: 0.286255, No Obj: 0.000112, .5R: 0.500000, .75R: 0.000000,  count: 2
# ...

# %%
# %%writefile rgb-task/obj.data
# classes=5
# train=./rgb-task/train.txt
# valid=./rgb-task/test.txt
# names=./rgb-task/obj.names
# backup =./rgb-task/backup/
# Out:
# Overwriting rgb-task/obj.data

# %%
cat obj.names
# Out:
# green_light
# red_light
# yellow_light
# not_lighted

# %%
# %%writefile obj.names
# green_light
# red_light
# yellow_light
# green_and_yellow_light
# not_lighted
# Out:
# Overwriting obj.names

# %%
#!./darknet detector train batawa_task/obj.data batawa_task/yolov3-obj.cfg task1/backup/yolov3-obj_4000.weights -dont_show -map
#!./darknet detector train batawa_task/obj.data batawa_task/yolov3-obj.cfg darknet53.conv.74 -dont_show -map
# !./darknet detector train batawa_task/obj.data batawa_task/yolov3-obj.cfg batawa_task/backup/yolov3-obj_1000.weights -dont_show -map
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# 1124: 0.100411, 0.091718 avg, 0.001000 rate, 4.637980 seconds, 71936 images
# Loaded: 0.000058 seconds
# Region 82 Avg IOU: 0.844491, Class: 0.999433, Obj: 0.849811, No Obj: 0.001665, .5R: 1.000000, .75R: 0.750000,  count: 4
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000005, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000002, .5R: -nan, .75R: -nan,  count: 0
# Region 82 Avg IOU: 0.730218, Class: 0.999221, Obj: 0.962550, No Obj: 0.001628, .5R: 1.000000, .75R: 0.500000,  count: 4
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000006, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000002, .5R: -nan, .75R: -nan,  count: 0
# Region 82 Avg IOU: 0.835838, Class: 0.999262, Obj: 0.994167, No Obj: 0.001708, .5R: 1.000000, .75R: 1.000000,  count: 4
# ...

# %%
# !wget https://image.itmedia.co.jp/mn/articles/2002/20/kmishima_patlite5_w590.jpg
# Out:
# --2021-03-07 19:26:59--  https://image.itmedia.co.jp/mn/articles/2002/20/kmishima_patlite5_w590.jpg
# Resolving image.itmedia.co.jp (image.itmedia.co.jp)... 54.249.27.217, 52.68.190.67, 13.230.217.145, ...
# Connecting to image.itmedia.co.jp (image.itmedia.co.jp)|54.249.27.217|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 98358 (96K) [image/jpeg]
# Saving to: ‘kmishima_patlite5_w590.jpg’
#
# kmishima_patlite5_w 100%[===================>]  96.05K   321KB/s    in 0.3s
#
# 2021-03-07 19:27:00 (321 KB/s) - ‘kmishima_patlite5_w590.jpg’ saved [98358/98358]

# %%
# ! ./darknet detector train task1/obj.data task1/yolov3-obj.cfg darknet53.conv.74 -dont_show -map
# !./darknet detector test rgb-task/obj.data rgb-task/yolov3-obj.cfg rgb-task/backup/yolov3-obj_600.weights kmishima_patlite3_w590.jpg -thresh 0.05
# Out:
# layer     filters    size              input                output
#     0 conv     32  3 x 3 / 1   608 x 608 x   3   ->   608 x 608 x  32  0.639 BFLOPs
#     1 conv     64  3 x 3 / 2   608 x 608 x  32   ->   304 x 304 x  64  3.407 BFLOPs
#     2 conv     32  1 x 1 / 1   304 x 304 x  64   ->   304 x 304 x  32  0.379 BFLOPs
#     3 conv     64  3 x 3 / 1   304 x 304 x  32   ->   304 x 304 x  64  3.407 BFLOPs
#     4 res    1                 304 x 304 x  64   ->   304 x 304 x  64
#     5 conv    128  3 x 3 / 2   304 x 304 x  64   ->   152 x 152 x 128  3.407 BFLOPs
#     6 conv     64  1 x 1 / 1   152 x 152 x 128   ->   152 x 152 x  64  0.379 BFLOPs
#     7 conv    128  3 x 3 / 1   152 x 152 x  64   ->   152 x 152 x 128  3.407 BFLOPs
#     8 res    5                 152 x 152 x 128   ->   152 x 152 x 128
#     9 conv     64  1 x 1 / 1   152 x 152 x 128   ->   152 x 152 x  64  0.379 BFLOPs
#    10 conv    128  3 x 3 / 1   152 x 152 x  64   ->   152 x 152 x 128  3.407 BFLOPs
# ...

# %%
# !./darknet detector map task1/obj.data task1/yolov3-obj.cfg task1/backup/yolov3-obj_6000.weights

# %%
# %%writefile task1/obj.data
# classes=1
# train=./task1/train.txt
# valid=./task1/test.txt
# names=./task1/obj.names
# backup=./task1/backup
# Out:
# Overwriting task1/obj.data

# %%
with open("task1/test.txt") as f:
  txt = f.read()
with open("task1/test2.txt", mode="w") as f:
  f.write(txt.replace("/content/drive/My Drive/darknet", "."))

# %%
import glob

images = glob.glob("/content/drive/My Drive/darknet/task1/data/*.jpeg")
cnt=0

with open("./task1/test.txt") as f:
  for line in f.readlines():
    print(line)
    if line in images:
      #print(line)
      pass
    else:
      #print(line, "error")
      cnt += 1
  print(len(images), "=", len(f.readlines()))

# %%
import os
import glob

imgs = glob.glob(r'./task1/data/*.jpeg')

for img in imgs:
  path1 = img
  path2 = img.replace(".jpeg", ".JPEG")
  os.rename(path1, path2) 

imgs = glob.glob(r'./task1/data/*.')
imgs
# Out:
# []

# %%
imgs = glob.glob(r'./task1/data/*.JPEG')
print(imgs)
# Out:
# ['./task1/data/OIP-8V9_3VNi56xXqzAk2OBS2gHaE--2.JPEG', './task1/data/OIP-9gTFaTmu4tGFmiNPMCrQNAHaCc-2.JPEG', './task1/data/OIP-8ziDhe9_X3WF7__-m15HVgHaEo-2.JPEG', './task1/data/OIP-8jiM4mnneAkgLquF8-JlCQHaEL-2.JPEG', './task1/data/OIP-8HYOzTAg5uy9GeQTqWgV0QAAAA-2.JPEG', './task1/data/OIP-9Dxk2-FlgbeuFXxM2kxwqwHaE8-2.JPEG', './task1/data/OIP-8iu0zJNam-hzUiSkyhMmqgHaCj-2.JPEG', './task1/data/OIP-8tmZAmdi_sAV40BLqQQYBQHaE7-2.JPEG', './task1/data/OIP-8M6b52nu4QiCvCqoGD_YHQHaE7-2.JPEG', './task1/data/OIP-9l4uKfJJWNIzDLp_39UupAHaEX-2.JPEG', './task1/data/OIP-8QH92rD3UKzUJe3yowMXfwHaE6-2.JPEG', './task1/data/OIP-9Ro3O-DpnsKarIHw3iejHgHaFj-2.JPEG', './task1/data/OIP-8_zgdxfbHPditvk7dlI2ewHaHZ-2.JPEG', './task1/data/OIP-9FHJ8IMu81PETHcHAD68rgHaG2-2.JPEG', './task1/data/OIP-9qZCws3TA9GXhkV-I_b69QAAAA-2.JPEG', './task1/data/OIP-9CRHNG768VumZpjBig7bQQHaE8-2.JPEG', './task1/data/OIP-991Ovfczr7TuKWRw0a9PBQHaFj-2.JPEG', './task1/data/OIP-9JR-d-IH3HfqKb2KBs7y_gHaE8-2.JPEG', './task1/data/OIP-8K0lKZ9
# ...
